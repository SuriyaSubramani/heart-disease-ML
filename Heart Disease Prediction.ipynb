# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
label=pd.read_csv('labels.csv')
label.head()
# Out:
#   patient_id  heart_disease_present
# 0     0z64un                      0
# 1     ryoo3j                      0
# 2     yt1s1x                      1
# 3     l2xjde                      1
# 4     oyt4ek                      0

# %%
value=pd.read_csv('values.csv')
value.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
data = pd.merge(value,label)

# %%
data
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %%
data.columns.value_counts()
# Out:
# patient_id                              1
# slope_of_peak_exercise_st_segment       1
# thal                                    1
# resting_blood_pressure                  1
# chest_pain_type                         1
# num_major_vessels                       1
# fasting_blood_sugar_gt_120_mg_per_dl    1
# resting_ekg_results                     1
# serum_cholesterol_mg_per_dl             1
# oldpeak_eq_st_depression                1
# sex                                     1
# age                                     1
# max_heart_rate_achieved                 1
# exercise_induced_angina                 1
# heart_disease_present                   1
# dtype: int64

# %%
data1=data.drop(['patient_id'],axis=1)

# %%
data1
# Out:
#      slope_of_peak_exercise_st_segment               thal  \
# 0                                    1             normal
# 1                                    2             normal
# 2                                    1             normal
# 3                                    1  reversible_defect
# 4                                    3  reversible_defect
# ..                                 ...                ...
# 175                                  2  reversible_defect
# 176                                  2             normal
# 177                                  2  reversible_defect
# 178                                  1             normal
# 179                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# 1                       110                3                  0
# 2                       125                4                  3
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   slope_of_peak_exercise_st_segment     180 non-null    int64
#  1   thal                                  180 non-null    object
#  2   resting_blood_pressure                180 non-null    int64
#  3   chest_pain_type                       180 non-null    int64
#  4   num_major_vessels                     180 non-null    int64
#  5   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  6   resting_ekg_results                   180 non-null    int64
#  7   serum_cholesterol_mg_per_dl           180 non-null    int64
#  8   oldpeak_eq_st_depression              180 non-null    float64
#  9   sex                                   180 non-null    int64
#  10  age                                   180 non-null    int64
# ...

# %%
data1.describe()
# Out:
#        slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# count                         180.000000              180.000000
# mean                            1.550000              131.311111
# std                             0.618838               17.010443
# min                             1.000000               94.000000
# 25%                             1.000000              120.000000
# 50%                             1.000000              130.000000
# 75%                             2.000000              140.000000
# max                             3.000000              180.000000
#
#        chest_pain_type  num_major_vessels  \
# count       180.000000         180.000000
# mean          3.155556           0.694444
# std           0.938454           0.969347
# min           1.000000           0.000000
# 25%           3.000000           0.000000
# 50%           3.000000           0.000000
# 75%           4.000000           1.000000
# ...

# %%
data1.thal.unique()
# Out:
# array(['normal', 'reversible_defect', 'fixed_defect'], dtype=object)

# %%
data1.thal=data1.thal.replace({'normal':2,'reversible_defect':1,'fixed_defect':0})

# %%
data1.thal
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      1
#       ..
# 175    1
# 176    2
# 177    1
# 178    2
# 179    2
# Name: thal, Length: 180, dtype: int64

# %%
data1.isnull().sum()
# Out:
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# resting_blood_pressure                  0
# chest_pain_type                         0
# num_major_vessels                       0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# oldpeak_eq_st_depression                0
# sex                                     0
# age                                     0
# max_heart_rate_achieved                 0
# exercise_induced_angina                 0
# heart_disease_present                   0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   slope_of_peak_exercise_st_segment     180 non-null    int64
#  1   thal                                  180 non-null    int64
#  2   resting_blood_pressure                180 non-null    int64
#  3   chest_pain_type                       180 non-null    int64
#  4   num_major_vessels                     180 non-null    int64
#  5   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  6   resting_ekg_results                   180 non-null    int64
#  7   serum_cholesterol_mg_per_dl           180 non-null    int64
#  8   oldpeak_eq_st_depression              180 non-null    float64
#  9   sex                                   180 non-null    int64
#  10  age                                   180 non-null    int64
# ...

# %% [markdown]
# # EDA

# %%
labels = ['yes', 'No']
values = data1['heart_disease_present'].value_counts().values

plt.pie(values, labels=labels, autopct='%1.0f%%')
plt.title('Heart Disease')
plt.legend(title = 'Heart Disease')
plt.show()

# %%
# Create a plot of crosstab
pd.crosstab(data1.heart_disease_present,data1.sex).plot(kind="bar",
                                    figsize=(10,6),
                                    color=["pink","blue"])
plt.title("heart disease frequency for sex")
plt.xlabel("0 = no disease, 1 = disease")
plt.ylabel("Amount")
plt.legend(["female", "male"])
plt.xticks(rotation=0);

# %%
sns.countplot(data1['age'])
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (5,5))
labels = ["Typical angina", "Atypical angina","non-anginal pain","asymptomatic"]
values = data1['chest_pain_type'].value_counts().tolist()
plt.pie(x=values, labels=labels, autopct="%1.1f%%",colors=['#AAb3ff','#CC80FF','#DD00AA','#FF0099'],shadow=True,startangle=45,explode=[0.1, 0.1, 0.1, 0.2])
ax.set_title("Chest Pain", fontdict={'fontsize': 12},fontweight ='bold')
# Out:
# Text(0.5, 1.0, 'Chest Pain')

# %%
sns.distplot(data1['thal'])
# Out:
# <AxesSubplot:xlabel='thal', ylabel='Density'>

# %%
data1.hist(figsize=(10,10),bins=50)
plt.show()

# %%
data1.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# slope_of_peak_exercise_st_segment          AxesSubplot(0.125,0.712609;0.168478x0.167391)
# thal                                    AxesSubplot(0.327174,0.712609;0.168478x0.167391)
# resting_blood_pressure                  AxesSubplot(0.529348,0.712609;0.168478x0.167391)
# chest_pain_type                         AxesSubplot(0.731522,0.712609;0.168478x0.167391)
# num_major_vessels                          AxesSubplot(0.125,0.511739;0.168478x0.167391)
# fasting_blood_sugar_gt_120_mg_per_dl    AxesSubplot(0.327174,0.511739;0.168478x0.167391)
# resting_ekg_results                     AxesSubplot(0.529348,0.511739;0.168478x0.167391)
# serum_cholesterol_mg_per_dl             AxesSubplot(0.731522,0.511739;0.168478x0.167391)
# oldpeak_eq_st_depression                    AxesSubplot(0.125,0.31087;0.168478x0.167391)
# sex                                      AxesSubplot(0.327174,0.31087;0.168478x0.167391)
# ...

# %%
data1.plot(kind ='density',subplots = True, layout =(4,4),sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
data1.hist(figsize=(10,10),bins=50)
plt.show()

# %%
sns.pairplot(data1)

# %%
data1.corr()
# Out:
#                                       slope_of_peak_exercise_st_segment  \
# slope_of_peak_exercise_st_segment                              1.000000
# thal                                                          -0.317019
# resting_blood_pressure                                         0.098287
# chest_pain_type                                                0.121207
# num_major_vessels                                              0.076832
# fasting_blood_sugar_gt_120_mg_per_dl                           0.050199
# resting_ekg_results                                            0.172191
# serum_cholesterol_mg_per_dl                                   -0.032348
# oldpeak_eq_st_depression                                       0.615948
# sex                                                            0.093340
# age                                                            0.169918
# max_heart_rate_achieved                                       -0.418102
# ...

# %%
corr_matrix = data1.corr()
fig, ax =plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,
                 annot =True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
# Out:
# (14.5, -0.5)

# %%
X = data1.drop("heart_disease_present",axis=1)
Y = data1["heart_disease_present"]
X
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                    1     2                     128
# 1                                    2     2                     110
# 2                                    1     2                     125
# 3                                    1     1                     152
# 4                                    3     1                     178
# ..                                 ...   ...                     ...
# 175                                  2     1                     125
# 176                                  2     2                     180
# 177                                  2     1                     125
# 178                                  1     2                     124
# 179                                  1     2                     160
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# ...

# %%
Y
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 175    1
# 176    1
# 177    1
# 178    0
# 179    0
# Name: heart_disease_present, Length: 180, dtype: int64

# %%
# split data into train and test sets
from sklearn.model_selection import train_test_split, cross_val_score
np.random.seed(42)

X_train, X_test, Y_train, Y_test =train_test_split(X,Y,test_size=0.2)

# %%
X_train.head()
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 117                                  1     1                     110
# 65                                   1     1                     126
# 67                                   2     2                     115
# 31                                   2     1                     150
# 12                                   1     2                     140
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# 117                4                  0                                     0
# 65                 4                  0                                     0
# 67                 4                  0                                     0
# 31                 4                  3                                     0
# 12                 3                  0                                     0
#
#      resting_ekg_results  serum_cholesterol_mg_per_dl  \
# ...

# %%
Y_train.head()
# Out:
# 117    1
# 65     1
# 67     0
# 31     1
# 12     1
# Name: heart_disease_present, dtype: int64

# %% [markdown]
# ## Using Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy Score: 0.8333333333333334

# %% [markdown]
# ## Using KNN:

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.5555555555555556

# %% [markdown]
# ## Using SVC:

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
pred_y = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,pred_y))
# Out:
# Accuracy Score: 0.4722222222222222

# %% [markdown]
# ## Using DecisionTree:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.75

# %% [markdown]
# ## Using GaussianNB:

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred3))
# Out:
# Accuracy Score: 0.8055555555555556

# %% [markdown]
# ## Using RandomForest:

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.8055555555555556

# %% [markdown]
# ## Using Xgboost:

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred5 = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred5))
# Out:
# Accuracy Score: 0.8333333333333334

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Log-Reg', 'KNN', 'SVC', 'Des-Tree', 'Gaus-NB', 'RandomForest', 'Xgboost']
students = [83.33,55.55,47.22,75.0,80.55,80.55,83.33]
ax.bar(langs,students)
plt.show()
